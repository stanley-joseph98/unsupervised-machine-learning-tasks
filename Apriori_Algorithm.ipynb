# %%
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
#!pip install mlxtend

# %%
# df = pd.read_excel('http://archive.ics.uci.edu/ml/machine-learning-databases/00352/Online%20Retail.xlsx')
# df.head(10)
# df.to_csv(r'C:\Users\USER\Desktop\ALL MY TASKS\online+retail+ii')

# %%
df  =pd.read_csv(r'C:\Users\USER\Desktop\ALL MY TASKS\online+retail+ii\retail_analysis_data.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'InvoiceNo', 'StockCode', 'Description', 'Quantity',
#        'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   541909 non-null  int64
#  1   InvoiceNo    541909 non-null  object
#  2   StockCode    541909 non-null  object
#  3   Description  540455 non-null  object
#  4   Quantity     541909 non-null  int64
#  5   InvoiceDate  541909 non-null  object
#  6   UnitPrice    541909 non-null  float64
#  7   CustomerID   406829 non-null  float64
#  8   Country      541909 non-null  object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 37.2+ MB

# %%
df['Description'].unique()
# Out:
# array(['WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN',
#        'CREAM CUPID HEARTS COAT HANGER', ..., 'lost',
#        'CREAM HANGING HEART T-LIGHT HOLDER',
#        'PAPER CRAFT , LITTLE BIRDIE'], dtype=object)

# %%
df['Description'] = df['Description'].str.strip() #removing spaces from the beginning of the data
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True) #removing duplicates invoice
df['InvoiceNo'] = df['InvoiceNo'].astype('str') 
df = df[~df['InvoiceNo'].str.contains('C')] #removes the credit transactions 
df.head(10)
# Out:
#    Unnamed: 0 InvoiceNo StockCode                          Description  \
# 0           0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1           1    536365     71053                  WHITE METAL LANTERN
# 2           2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3           3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4           4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# 5           5    536365     22752         SET 7 BABUSHKA NESTING BOXES
# 6           6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER
# 7           7    536366     22633               HAND WARMER UNION JACK
# 8           8    536366     22632            HAND WARMER RED POLKA DOT
# 9           9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT
#
#    Quantity          InvoiceDate  UnitPrice  CustomerID         Country
# 0         6  2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1         6  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2         8  2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3         6  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4         6  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 5         2  2010-12-01 08:26:00       7.65     17850.0  United Kingdom
# 6         6  2010-12-01 08:26:00       4.25     17850.0  United Kingdom
# 7         6  2010-12-01 08:28:00       1.85     17850.0  United Kingdom
# 8         6  2010-12-01 08:28:00       1.85     17850.0  United Kingdom
# 9        32  2010-12-01 08:34:00       1.69     13047.0  United Kingdom

# %%
items_saudia_bought = df[df['Country'] == 'Saudi Arabia']['Description'].unique()
print(items_saudia_bought)
# Out:
# ['ASSORTED BOTTLE TOP  MAGNETS' 'GLASS JAR MARMALADE'
#  'GLASS JAR PEACOCK BATH SALTS' 'GLASS JAR DAISY FRESH COTTON WOOL'
#  'PLASTERS IN TIN SKULLS' 'PLASTERS IN TIN STRONGMAN'
#  'PLASTERS IN TIN CIRCUS PARADE' 'GOLD EAR MUFF HEADPHONES'
#  'HOMEMADE JAM SCENTED CANDLES']

# %%
items_canadian_bought = df[df['Country'] == 'Canada']['Description'].unique()
print(items_canadian_bought)
# Out:
# ['BOX OF 9 PEBBLE CANDLES' 'TUMBLER, BAROQUE' 'SILVER STANDING GNOME'
#  'ASSORTED COLOUR BIRD ORNAMENT' 'COLOUR GLASS T-LIGHT HOLDER HANGING'
#  'BLACK CANDELABRA T-LIGHT HOLDER' 'HANGING JAM JAR T-LIGHT HOLDER'
#  'PAINTED METAL PEARS ASSORTED' 'VINTAGE UNION JACK CUSHION COVER'
#  'MOROCCAN TEA GLASS' 'RETRO COFFEE MUGS ASSORTED'
#  'PACK OF 60 SPACEBOY CAKE CASES' '60 CAKE CASES DOLLY GIRL DESIGN'
#  'APRON APPLE DELIGHT' 'BULL DOG BOTTLE OPENER'
#  'SET/3 DECOUPAGE STACKING TINS' 'BLACK KITCHEN SCALES'
#  'CHILDS BREAKFAST SET DOLLY GIRL' 'CHILDS BREAKFAST SET SPACEBOY'
#  'SET OF 5 LUCKY CAT MAGNETS' 'TV DINNER TRAY DOLLY GIRL'
#  'TV DINNER TRAY AIR HOSTESS' 'SPACEBOY TV DINNER TRAY'
#  'SET 12 KIDS COLOUR  CHALK STICKS' 'SET 12 KIDS  WHITE CHALK STICKS'
#  'REVOLVER WOODEN RULER' 'WOODEN SCHOOL COLOURING SET'
#  'COLOURING PENCILS BROWN TUBE' 'PACK OF 12 COLOURED PENCILS'
#  'PACK OF 12 TRADITIONAL CRAYONS' 'WRAP BAD HAIR DAY' 'WRAP CAROUSEL'
#  'WRAP ENGLISH ROSE' 'SPACEBOY GIFT WRAP' 'WRAP RED APPLES'
#  'WRAP GREEN PEARS' 'GINGHAM ROSE WRAP' 'WRAP DOILEY DESIGN'
#  'BUNDLE OF 3 RETRO NOTE BOOKS' 'BUNDLE OF 3 ALPHABET EXERCISE BOOKS'
#  'BUNDLE OF 3 SCHOOL EXERCISE BOOKS' 'ALARM CLOCK BAKELIKE ORANGE'
#  'BLACK BAROQUE WALL CLOCK' 'BLACK BAROQUE CARRIAGE CLOCK'
#  'GRASS HOPPER WOODEN WALL CLOCK' 'ALARM CLOCK BAKELIKE RED'
#  'WORLD WAR 2 GLIDERS ASSTD DESIGNS' 'LUNCH BAG  BLACK SKULL.'
#  'LUNCH BAG SPACEBOY DESIGN' 'LUNCH BAG SUKI DESIGN'
#  'BAKING SET SPACEBOY DESIGN' 'BAKING SET 9 PIECE RETROSPOT'
#  'AIRLINE BAG VINTAGE WORLD CHAMPION' 'SKULL LUNCH BOX WITH CUTLERY'
#  'CHILDRENS APRON SPACEBOY DESIGN' 'LUNCH BAG APPLE DESIGN'
#  'ABC TREASURE BOOK BOX' 'BUFFALO BILL TREASURE BOOK BOX'
#  'TREASURE ISLAND BOOK BOX' 'GENTLEMAN SHIRT REPAIR KIT'
#  'TRAVEL SEWING KIT' 'SEWING SUSAN 21 NEEDLE SET'
#  'CONDIMENT TRAY 4 BOWLS AND 4 SPOONS' 'SAVE THE PLANET MUG'
#  'HOME SWEET HOME MUG' 'PIG MUG IN TWO COLOUR DESIGNS'
#  'PACK OF 60 DINOSAUR CAKE CASES' 'BLACK TEA,COFFEE,SUGAR JARS'
#  'WHITE TEA,COFFEE,SUGAR JARS' 'LA PALMIERA TILE COASTER'
#  'BLUE ROUND COMPACT MIRROR' 'WAKE UP COCKEREL TILE COASTER'
#  'GREEN ROUND COMPACT MIRROR' 'SQUARE CHERRY BLOSSOM CABINET'
#  'TUMBLER BAROQUE' 'SCOTTIE DOGS BABY BIB'
#  'PINK/WHITE CHRISTMAS TREE 60CM' 'MAGNETS PACK OF 4 VINTAGE COLLAGE'
#  'MAGNETS PACK OF 4 RETRO PHOTO' 'MAGNETS PACK OF 4 SWALLOWS'
#  'MAGNETS PACK OF 4 VINTAGE LABELS' 'MAGNETS PACK OF 4 HOME SWEET HOME'
#  'BOUDOIR SQUARE TISSUE BOX' 'CARAVAN SQUARE TISSUE BOX'
#  'SKULLS SQUARE TISSUE BOX' 'MOTORING TISSUE BOX'
#  'RED RETROSPOT TISSUE BOX' 'NO JUNK MAIL METAL SIGN'
#  '12 PENCILS TALL TUBE POSY' 'HELLO SAILOR BLUE SOAP HOLDER'
#  'PURPLE PAPER PARASOL' 'PINK PAPER PARASOL' 'RED PAPER PARASOL'
#  'YELLOW COAT RACK PARIS FASHION' 'BLUE COAT RACK PARIS FASHION'
#  'RED COAT RACK PARIS FASHION' 'METAL SIGN,CUPCAKE SINGLE HOOK'
#  'METAL SIGN CUPCAKE SINGLE HOOK' 'MINIATURE ANTIQUE ROSE HOOK IVORY'
#  "CHILDREN'S APRON DOLLY GIRL" 'IVORY KITCHEN SCALES'
#  'MINT KITCHEN SCALES' 'LUNCH BAG WOODLAND' 'LUNCH BAG CARS BLUE'
#  'STRAWBERRY LUNCH BOX WITH CUTLERY' 'DOLLY GIRL LUNCH BOX'
#  'CIRCUS PARADE LUNCH BOX' 'LUNCH BAG DOLLY GIRL DESIGN'
#  'LUNCH BAG ALPHABET DESIGN' 'LUNCH BAG VINTAGE LEAF DESIGN'
#  'REGENCY TEA PLATE ROSES' 'REGENCY TEA PLATE PINK'
#  'REGENCY TEA PLATE GREEN' 'DANISH ROSE DECORATIVE PLATE'
#  'REGENCY SUGAR BOWL GREEN' 'REGENCY MILK JUG PINK'
#  'PINK DOUGHNUT TRINKET POT' 'STRAWBERRY CERAMIC TRINKET BOX'
#  'REGENCY CAKESTAND 3 TIER' 'CHILDS BREAKFAST SET CIRCUS PARADE'
#  'ROSES REGENCY TEACUP AND SAUCER' 'GREEN REGENCY TEACUP AND SAUCER'
#  'STRAWBERRY FAIRY CAKE TEAPOT' 'REGENCY TEAPOT ROSES'
#  'PLASTERS IN TIN WOODLAND ANIMALS' 'PLASTERS IN TIN STRONGMAN'
#  'PLASTERS IN TIN SPACEBOY' 'PLASTERS IN TIN CIRCUS PARADE'
#  'BLUE TRAVEL FIRST AID KIT' 'DINOSAUR KEYRINGS ASSORTED'
#  'SET OF 6 NATIVITY MAGNETS' 'SET OF 5 PANCAKE DAY MAGNETS'
#  '10 COLOUR SPACEBOY PEN' 'SMALL YELLOW BABUSHKA NOTEBOOK'
#  'SMALL RED BABUSHKA NOTEBOOK' 'TREASURE TIN GYMKHANA DESIGN'
#  'TREASURE TIN BUFFALO BILL' '4 TRADITIONAL SPINNING TOPS'
#  'SET OF 6 SOLDIER SKITTLES' 'TRADITIONAL WOODEN CATCH CUP GAME'
#  'BAG 125g SWIRLY MARBLES' 'POSTAGE' 'FLORAL FOLK STATIONERY SET'
#  'SET OF 12 MINI LOAF BAKING CASES' 'SET OF 12 FAIRY CAKE BAKING CASES'
#  'SET OF 6 TEA TIME BAKING CASES' 'SET OF 6 SNACK LOAF BAKING CASES']

# %%
customer_info = df.loc[df['InvoiceNo'] == '573585', ['CustomerID', 'Country','Description']]
if not customer_info.empty:
    print(customer_info.iloc[59:73])
else:
    print("No information found for the given InvoiceNo.")
# Out:
#         CustomerID         Country                         Description
# 430296         NaN  United Kingdom                   APPLE BATH SPONGE
# 430297         NaN  United Kingdom   RED FLORAL FELTCRAFT SHOULDER BAG
# 430298         NaN  United Kingdom  PINK FLORAL FELTCRAFT SHOULDER BAG
# 430299         NaN  United Kingdom    PINK BLUE FELT CRAFT TRINKET BOX
# 430300         NaN  United Kingdom   PINK CREAM FELT CRAFT TRINKET BOX
# 430301         NaN  United Kingdom       12 PENCIL SMALL TUBE WOODLAND
# 430302         NaN  United Kingdom              36 PENCILS TUBE SKULLS
# 430303         NaN  United Kingdom       36 PENCILS TUBE RED RETROSPOT
# 430304         NaN  United Kingdom         12 PENCILS TALL TUBE SKULLS
# 430305         NaN  United Kingdom  12 PENCILS TALL TUBE RED RETROSPOT
# 430306         NaN  United Kingdom                    HEART CALCULATOR
# 430307         NaN  United Kingdom           ROSE DU SUD CUSHION COVER
# 430308         NaN  United Kingdom       ANTIQUE ALL GLASS CANDLESTICK
# 430309         NaN  United Kingdom        SWISS CHALET TREE DECORATION

# %%
df.shape
# Out:
# (532621, 9)

# %%
df['CustomerID'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 532621 entries, 0 to 541908
# Series name: CustomerID
# Non-Null Count   Dtype
# --------------   -----
# 397924 non-null  float64
# dtypes: float64(1)
# memory usage: 8.1 MB

# %%
df['InvoiceNo'].value_counts()
# Out:
# InvoiceNo
# 573585    1114
# 581219     749
# 581492     731
# 580729     721
# 558475     705
#           ...
# 547989       1
# 547991       1
# 569895       1
# 547994       1
# 547916       1
# Name: count, Length: 22064, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# Country
# United Kingdom          487622
# Germany                   9042
# France                    8408
# EIRE                      7894
# Spain                     2485
# Netherlands               2363
# Belgium                   2031
# Switzerland               1967
# Portugal                  1501
# Australia                 1185
# Norway                    1072
# Italy                      758
# Channel Islands            748
# Finland                    685
# Cyprus                     614
# Sweden                     451
# Unspecified                446
# Austria                    398
# Denmark                    380
# Poland                     330
# Japan                      321
# Israel                     295
# Hong Kong                  284
# Singapore                  222
# Iceland                    182
# USA                        179
# Canada                     151
# Greece                     145
# Malta                      112
# United Arab Emirates        68
# European Community          60
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              25
# Bahrain                     18
# Saudi Arabia                 9
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (532621, 9)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'InvoiceNo', 'StockCode', 'Description', 'Quantity',
#        'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
#Separating transactions for a certain country

germanBasket = (df[df['Country'] == 'Germany']
               .groupby(['InvoiceNo','Description'])['Quantity']
               .sum().unstack().reset_index().fillna(0).set_index('InvoiceNo'))
germanBasket.head(20)
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 
.0
#
# Description  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo
# 536527                                    0.0
# 536840                                    0.0
# 536861                                    0.0
# 536967                                    0.0
# 536983                                    0.0
# 537197                                    0.0
# 537198                                    0.0
# 537201                                    0.0
# 537212                                    0.0
# 537250                                    0.0
# 537594                                    0.0
# 537673                                    0.0
# 537892                                    0.0
# 537894                                    0.0
# 537995                                    0.0
# 538174                                    0.0
# 538175                                    0.0
# 538644                                    0.0
# 539327                                    0.0
# 539395                                    0.0
#
# [20 rows x 1695 columns]

# %%
#Encoding the dataset by converting every positive values to 1 and everything else to zero

def my_encoded_units(x):
    if x <=0:
        return 0
    if x >= 1:
        return 1
    
german_basket_sets = germanBasket.applymap(my_encode_units)
#german_basket_sets.drop('POSTAGE', inplace=True, axis=1)

# %% [markdown]
# # Training apriori model

# %%
#Generates frequent itemsets:
import warnings
warnings.filterwarnings("ignore")
german_frequent_itemsets = apriori(german_basket_sets, min_support=0.07, use_colnames=True)

# %%
#Let's set the rules:
german_rules = association_rules(german_frequent_itemsets, metric='lift', min_threshold=2)

# %%
#Let us see the top 100 rules
german_rules.head(100)
# Out:
#                             antecedents                           consequents  \
# 0    (PLASTERS IN TIN WOODLAND ANIMALS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 1  (ROUND SNACK BOXES SET OF4 WOODLAND)    (PLASTERS IN TIN WOODLAND ANIMALS)
# 2   (ROUND SNACK BOXES SET OF 4 FRUITS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 3  (ROUND SNACK BOXES SET OF4 WOODLAND)   (ROUND SNACK BOXES SET OF 4 FRUITS)
# 4                  (SPACEBOY LUNCH BOX)  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 5  (ROUND SNACK BOXES SET OF4 WOODLAND)                  (SPACEBOY LUNCH BOX)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.137856            0.245077  0.074398    0.539683  2.202098
# 1            0.245077            0.137856  0.074398    0.303571  2.202098
# 2            0.157549            0.245077  0.131291    0.833333  3.400298
# 3            0.245077            0.157549  0.131291    0.535714  3.400298
# 4            0.102845            0.245077  0.070022    0.680851  2.778116
# 5            0.245077            0.102845  0.070022    0.285714  2.778116
#
#    leverage  conviction  zhangs_metric
# 0  0.040613    1.640006       0.633174
# 1  0.040613    1.237951       0.723103
# 2  0.092679    4.529540       0.837922
# 3  0.092679    1.814509       0.935072
# 4  0.044817    2.365427       0.713415
# 5  0.044817    1.256018       0.847826

# %% [markdown]
# # We can now make recommendations based on this rule

# %%
german_rules['antecedents'].unique()
# Out:
# array([frozenset({'PLASTERS IN TIN WOODLAND ANIMALS'}),
#        frozenset({'ROUND SNACK BOXES SET OF4 WOODLAND'}),
#        frozenset({'ROUND SNACK BOXES SET OF 4 FRUITS'}),
#        frozenset({'SPACEBOY LUNCH BOX'})], dtype=object)

# %%
german_basket_sets['ROUND SNACK BOXES SET OF4 WOODLAND'].sum()
# Out:
# 112

# %%
#Filtering rules based on conditions
german_rules[(german_rules['lift'] >= 3) &
            (german_rules['confidence'] >= 0.3)]
# Out:
#                             antecedents                           consequents  \
# 2   (ROUND SNACK BOXES SET OF 4 FRUITS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 3  (ROUND SNACK BOXES SET OF4 WOODLAND)   (ROUND SNACK BOXES SET OF 4 FRUITS)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 2            0.157549            0.245077  0.131291    0.833333  3.400298
# 3            0.245077            0.157549  0.131291    0.535714  3.400298
#
#    leverage  conviction  zhangs_metric
# 2  0.092679    4.529540       0.837922
# 3  0.092679    1.814509       0.935072
